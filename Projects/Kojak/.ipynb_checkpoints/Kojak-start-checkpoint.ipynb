# %% [markdown]
# #Project Kojak

# %%
import pandas as pd
import numpy as np
import math

# %%
def time_exp(tj, ti):
    return math.exp(-(tj - ti))

# %%
def space_exp(xj, xi, yj, yi): 
    return math.exp(- ((xj-xi)**2 + (yj - yi)**2) / 2)

# %%
def background_kernel(x,y):
    '''
    We define categories as an array of all crime categories.
    number_of_all_events is a global variable defining (K) length of the dataset being used
    '''
    for i in range(0,number_of_all_events):
        calculate_alpha(i)

# %%
def intensity(x, y, t):
    for i in range(0,len(?)):
        #calculate background kernel
    for i in range(0, len(?)):
        #calculate trigger kernel
# Out:
#   File "<ipython-input-59-c30765acdf01>", line 2
#     for i in range(0,len(?)):
#                          ^
# SyntaxError: invalid syntax

# %%
def trigger_probability(i,j,category):
    #category should be an array of the category with time, x and y values
    part1 = (theta[i] * omega * time_matrix[i,j]**omega * space_matrix**sigma_squared) / (2*math.Pi*sigma_squared)
    total = part1 / intensity(category[1][j], category[2][j], category[0][j])
    return total

# %%
def background_probability(i, j, category):
    #category should be an array of the category with time, x and y values
    part1 = (alpha[i] * space_matrix[i,j]**eta_squared) / (2 * np.pi * eta_squared)
    total = part1 / (T * intensity(category[1][j],category[2][j],category[0][j]))
    return total

# %%
def calculate_omega():
    part1 = trigger_matrix.sum()
    part2 = np.multiply(trigger_matrix,time_matrix).sum()
    part3 = 0
    return part1 / (part2 + part3)

# %%
def calculat_sigma_squared():
    part1 = 0
    part2 = 0
    return part1 / part2

# %%
def calculate_eta_squared():
    part1 = 0
    part2 = 0
    return part1 / part2

# %%
def calculate_theta(i):
    part1 = 0
    part2 = 0
    return part1 / part2

# %%
def calculate_alpha(i):
    part1 = 0
    return part1 / len(category[i]) #divide by number of events of this category

# %%
# !ls
# Out:
# CPD-crime-2007-2012                      Kojak-start.ipynb                        SF_Urban_Tree_Canopy
# CPD-model-data-2007-2012                 Presentation.key                         building_footprint
# Crimes_-_2001_to_present.csv             SFPD_Incidents_-_from_1_January_2003.csv kojak.py

# %%
cpd_df = pd.read_csv("CPD-model-data-2007-2012")

# %%
cpd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540759 entries, 0 to 540758
# Data columns (total 14 columns):
# Unnamed: 0              540759 non-null int64
# Date                    540759 non-null object
# Block                   540759 non-null object
# Primary Type            540759 non-null object
# Description             540759 non-null object
# Location Description    540754 non-null object
# Arrest                  540759 non-null bool
# Domestic                540759 non-null bool
# District                540743 non-null float64
# Ward                    540752 non-null float64
# Community Area          540546 non-null float64
# Latitude                540759 non-null float64
# Longitude               540759 non-null float64
# Location                540759 non-null object
# dtypes: bool(2), float64(5), int64(1), object(6)
# memory usage: 54.7+ MB

# %%
cpd_df['Date'] = pd.to_datetime(cpd_df['Date'])

# %%
cpd_df
# Out:
#         Unnamed: 0                Date                    Block  \
# 0           886855 2013-01-01 00:00:00        076XX S UNION AVE
# 1           886861 2013-01-01 00:00:00        078XX S ESSEX AVE
# 2           886891 2013-01-01 00:00:00  012XX S SPRINGFIELD AVE
# 3           886914 2012-12-31 23:45:00   026XX N CALIFORNIA AVE
# 4           886915 2012-12-31 23:45:00     070XX S ELIZABETH ST
# 5           886916 2012-12-31 23:43:00       063XX S PAULINA ST
# 6           886918 2012-12-31 23:40:00        022XX N AVERS AVE
# 540753     3195910 2007-01-04 08:17:00       009XX N KARLOV AVE
# 540754     3197754 2007-01-02 14:58:00         023XX S STATE ST
# 540755     3199054 2007-01-01 09:43:00    071XX S CONSTANCE AVE
# 540756     3199441 2007-01-01 03:10:00     030XX S ST LOUIS AVE
# 540757     3199558 2007-01-01 02:09:00          047XX W OHIO ST
# 540758     3199733 2007-01-01 00:15:00          020XX W 70TH ST
#
#                Primary Type                          Description  \
# 0       CRIM SEXUAL ASSAULT                            PREDATORY
# 1       CRIM SEXUAL ASSAULT                            PREDATORY
# 2       CRIM SEXUAL ASSAULT                            PREDATORY
# 3                   BATTERY              DOMESTIC BATTERY SIMPLE
# 4                   BATTERY              DOMESTIC BATTERY SIMPLE
# 5                   ASSAULT               AGGRAVATED PO: HANDGUN
# 6                   BATTERY  AGG: HANDS/FIST/FEET SERIOUS INJURY
# 7                   BATTERY                               SIMPLE
# 8                   BATTERY              DOMESTIC BATTERY SIMPLE
# 9                   BATTERY              DOMESTIC BATTERY SIMPLE
# 10                  BATTERY  AGG: HANDS/FIST/FEET SERIOUS INJURY
# 11                  BATTERY              DOMESTIC BATTERY SIMPLE
# 12                  BATTERY              DOMESTIC BATTERY SIMPLE
# 13                  BATTERY        AGGRAVATED: OTHER DANG WEAPON
# 14                  BATTERY              DOMESTIC BATTERY SIMPLE
# 15                  BATTERY              DOMESTIC BATTERY SIMPLE
# 16        WEAPONS VIOLATION             UNLAWFUL POSS OF HANDGUN
# 17                  BATTERY              DOMESTIC BATTERY SIMPLE
# 18                  BATTERY                               SIMPLE
# 19        WEAPONS VIOLATION             UNLAWFUL POSS OF HANDGUN
# 20        WEAPONS VIOLATION             UNLAWFUL POSS OF HANDGUN
# 21                  ASSAULT                               SIMPLE
# 22                  BATTERY                               SIMPLE
# 23                  ASSAULT                               SIMPLE
# 24                  BATTERY        AGGRAVATED: OTHER DANG WEAPON
# 25                  ROBBERY                STRONGARM - NO WEAPON
# 26                  BATTERY              DOMESTIC BATTERY SIMPLE
# 27                  BATTERY                               SIMPLE
# 28                  BATTERY              DOMESTIC BATTERY SIMPLE
# 29                  ASSAULT                               SIMPLE
# ...                     ...                                  ...
# 540729             HOMICIDE                  FIRST DEGREE MURDER
# 540730             HOMICIDE                  FIRST DEGREE MURDER
# 540731             HOMICIDE                  FIRST DEGREE MURDER
# 540732             HOMICIDE                  FIRST DEGREE MURDER
# 540733             HOMICIDE                  FIRST DEGREE MURDER
# 540734             HOMICIDE                  FIRST DEGREE MURDER
# 540735             HOMICIDE                  FIRST DEGREE MURDER
# 540736             HOMICIDE                  FIRST DEGREE MURDER
# 540737             HOMICIDE                  FIRST DEGREE MURDER
# 540738             HOMICIDE                  FIRST DEGREE MURDER
# 540739             HOMICIDE                  FIRST DEGREE MURDER
# 540740             HOMICIDE                  FIRST DEGREE MURDER
# 540741             HOMICIDE                  FIRST DEGREE MURDER
# 540742             HOMICIDE                  FIRST DEGREE MURDER
# 540743             HOMICIDE                  FIRST DEGREE MURDER
# 540744             HOMICIDE                  FIRST DEGREE MURDER
# 540745             HOMICIDE                  FIRST DEGREE MURDER
# 540746             HOMICIDE                  FIRST DEGREE MURDER
# 540747             HOMICIDE                  FIRST DEGREE MURDER
# 540748             HOMICIDE                  FIRST DEGREE MURDER
# 540749             HOMICIDE                  FIRST DEGREE MURDER
# 540750             HOMICIDE                  FIRST DEGREE MURDER
# 540751             HOMICIDE                  FIRST DEGREE MURDER
# 540752             HOMICIDE                  FIRST DEGREE MURDER
# 540753             HOMICIDE                  FIRST DEGREE MURDER
# 540754             HOMICIDE                  FIRST DEGREE MURDER
# 540755             HOMICIDE                  FIRST DEGREE MURDER
# 540756             HOMICIDE                  FIRST DEGREE MURDER
# 540757             HOMICIDE                  FIRST DEGREE MURDER
# 540758             HOMICIDE                  FIRST DEGREE MURDER
#
#        Location Description Arrest Domestic  District  Ward  Community Area  \
# 0                 APARTMENT   True    False         6    17              71
# 1                 RESIDENCE  False     True         4     7              43
# 2                 RESIDENCE  False    False        10    24              29
# 3                 APARTMENT  False     True        14    35              22
# 4                 APARTMENT  False     True         7    17              67
# 5                    STREET  False    False         7    15              67
# 6                 APARTMENT   True    False        25    30              22
# 7                    STREET  False    False         1     2              32
# 8                    STREET   True     True        15    29              25
# 9                 APARTMENT   True     True         7    16              67
# 10                 SIDEWALK  False    False        18    42               8
# 11                APARTMENT   True     True         7     6              68
# 12                RESIDENCE  False     True         5     9              50
# 13                   STREET  False    False        12     2              27
# 14                APARTMENT   True     True        12     1              24
# 15                RESIDENCE  False     True        25    31              19
# 16                 SIDEWALK   True    False         7    15              67
# 17                APARTMENT  False     True        15    28              25
# 18                  CTA BUS   True    False         3     5              43
# 19                 SIDEWALK   True    False         9    16              61
# 20                RESIDENCE   True    False         9    16              61
# 21               RESTAURANT   True    False        18    42               8
# 22                    OTHER   True    False        20    46               3
# 23                RESIDENCE   True    False        16    45              11
# 24                   STREET  False    False        25    26              23
# 25                 SIDEWALK  False    False        12     2              28
# 26                RESIDENCE  False     True         7    16              67
# 27                   STREET  False    False        25    37              25
# 28                    OTHER  False     True         6    17              69
# 29                RESIDENCE  False     True         2     4              39
# ...                     ...    ...      ...       ...   ...             ...
# 540729                 AUTO   True    False        11    24              26
# 540730                 AUTO   True    False         4    10              46
# 540731                 AUTO   True    False         5     9              53
# 540732        CHA APARTMENT   True     True        18    27               8
# 540733            APARTMENT   True    False        11    27              23
# 540734            APARTMENT   True    False        11    27              23
# 540735               STREET   True    False         7     3              68
# 540736               STREET   True     True         7    16              68
# 540737                ALLEY   True     True        15    37              25
# 540738                ALLEY  False    False         7     6              69
# 540739            APARTMENT   True    False        15    28              25
# 540740            APARTMENT  False    False         9    16              61
# 540741            APARTMENT   True     True         2     4              35
# 540742                 AUTO  False    False         4     8              45
# 540743            APARTMENT   True    False        15    37              25
# 540744                ALLEY   True    False        14     1              24
# 540745               STREET   True    False         7    16              67
# 540746                PORCH  False    False        25    30              23
# 540747               STREET   True    False         7    16              67
# 540748            APARTMENT  False     True        10    22              30
# 540749            APARTMENT   True     True         2     3              40
# 540750                 AUTO   True    False         6    18              71
# 540751            APARTMENT  False    False         2    20              40
# 540752   GARAGE/AUTO REPAIR  False    False        11    28              26
# 540753         RETAIL STORE  False    False        11    37              23
# 540754          CHA HALLWAY   True    False         1     3              33
# 540749  41.801062 -87.624249  (41.801062213, -87.624248541)
# 540750  41.738550 -87.663134   (41.73855005, -87.663133974)
# 540751  41.790234 -87.623976  (41.790234333, -87.623975522)
# 540752  41.880628 -87.733911  (41.880628389, -87.733911427)
# 540753  41.898156 -87.728631  (41.898155638, -87.728630875)
# 540754  41.850331 -87.627026  (41.850330711, -87.627026373)
# 540755  41.765559 -87.580587  (41.765558758, -87.580587091)
# 540756  41.838092 -87.712177  (41.838092148, -87.712176626)
# 540757  41.891401 -87.744315  (41.891401248, -87.744314763)
# 540758  41.766616 -87.674436  (41.766615573, -87.674436286)
#
# [540759 rows x 14 columns]

# %%
np.sort(cpd_df['Primary Type'].unique())
# Out:
# array(['ASSAULT', 'BATTERY', 'CRIM SEXUAL ASSAULT', 'HOMICIDE', 'ROBBERY',
#        'WEAPONS VIOLATION'], dtype=object)

# %%
len(cpd_df[cpd_df['Primary Type'] == 'ASSAULT'])
# Out:
# 109661

# %%
print("Number of Homicides: %i" % len(cpd_df[cpd_df['Primary Type'] == 'HOMICIDE']))
print("Number of Robberies: %i" % len(cpd_df[cpd_df['Primary Type'] == 'ROBBERY']))
print("Number of Assaults: %i" % len(cpd_df[cpd_df['Primary Type'] == 'ASSAULT']))
print("Number of Weapons violation: %i" % len(cpd_df[cpd_df['Primary Type'] == 'WEAPONS VIOLATION']))
print("Number of Batteries: %i" % len(cpd_df[cpd_df['Primary Type'] == 'BATTERY']))
print("Number of Sexual Assaults: %i" % len(cpd_df[cpd_df['Primary Type'] == 'CRIM SEXUAL ASSAULT']))
# Out:
# Number of Homicides: 2800
# Number of Robberies: 74123
# Number of Assaults: 109661
# Number of Weapons violation: 19369
# Number of Batteries: 328004
# Number of Sexual Assaults: 6802

# %%
print(np.sort(cpd_df[cpd_df['Primary Type'] == 'ROBBERY']['Description'].unique()))
print(np.sort(cpd_df[cpd_df['Primary Type'] == 'ASSAULT']['Description'].unique()))
print(np.sort(cpd_df[cpd_df['Primary Type'] == 'WEAPONS VIOLATION']['Description'].unique()))
print(np.sort(cpd_df[cpd_df['Primary Type'] == 'BATTERY']['Description'].unique()))
print(np.sort(cpd_df[cpd_df['Primary Type'] == 'CRIM SEXUAL ASSAULT']['Description'].unique()))
# Out:
# ['AGGRAVATED' 'AGGRAVATED VEHICULAR HIJACKING' 'ARMED: HANDGUN'
#  'ARMED: OTHER DANGEROUS WEAPON' 'ARMED: OTHER FIREARM'
#  'ARMED:KNIFE/CUTTING INSTRUMENT' 'ATTEMPT: AGGRAVATED'
#  'ATTEMPT: ARMED-HANDGUN' 'ATTEMPT: ARMED-KNIFE/CUT INSTR'
#  'ATTEMPT: ARMED-OTHER DANG WEAP' 'ATTEMPT: ARMED-OTHER FIREARM'
#  'ATTEMPT: STRONGARM-NO WEAPON' 'STRONGARM - NO WEAPON'
#  'VEHICULAR HIJACKING']
# ['AGG PO HANDS NO/MIN INJURY' 'AGG PRO.EMP: HANDGUN'
#  'AGG PRO.EMP: OTHER DANG WEAPON' 'AGG PRO.EMP: OTHER FIREARM'
#  'AGG PRO.EMP:KNIFE/CUTTING INST' 'AGGRAVATED PO: HANDGUN'
#  'AGGRAVATED PO: OTHER DANG WEAP' 'AGGRAVATED PO: OTHER FIREARM'
#  'AGGRAVATED PO:KNIFE/CUT INSTR' 'AGGRAVATED: HANDGUN'
#  'AGGRAVATED: OTHER DANG WEAPON' 'AGGRAVATED: OTHER FIREARM'
#  'AGGRAVATED:KNIFE/CUTTING INSTR' 'PRO EMP HANDS NO/MIN INJURY' 'SIMPLE']
# ['DEFACE IDENT MARKS OF FIREARM' 'POSS FIREARM/AMMO:NO FOID CARD'
#  'RECKLESS FIREARM DISCHARGE' 'REGISTER OF SALES BY DEALER'
#  'UNLAWFUL POSS AMMUNITION' 'UNLAWFUL POSS OF HANDGUN'
#  'UNLAWFUL POSS OTHER FIREARM' 'UNLAWFUL SALE HANDGUN'
#  'UNLAWFUL SALE OTHER FIREARM'
#  'UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL' 'UNLAWFUL USE HANDGUN'
#  'UNLAWFUL USE OTHER DANG WEAPON' 'UNLAWFUL USE OTHER FIREARM'
#  'UNLAWFUL USE/SALE AIR RIFLE' 'USE OF METAL PIERCING BULLETS']
# ['AGG PO HANDS ETC SERIOUS INJ' 'AGG PO HANDS NO/MIN INJURY'
#  'AGG PRO EMP HANDS SERIOUS INJ' 'AGG PRO.EMP: HANDGUN'
#  'AGG PRO.EMP: OTHER DANG WEAPON' 'AGG PRO.EMP: OTHER FIREARM'
#  'AGG PRO.EMP:KNIFE/CUTTING INST' 'AGG: HANDS/FIST/FEET NO/MINOR INJURY'
#  'AGG: HANDS/FIST/FEET SERIOUS INJURY' 'AGGRAVATED DOMESTIC BATTERY'
#  'AGGRAVATED DOMESTIC BATTERY: HANDGUN'
#  'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY'
#  'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST'
#  'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON'
#  'AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM' 'AGGRAVATED OF A CHILD'
#  'AGGRAVATED OF A SENIOR CITIZEN' 'AGGRAVATED OF A UNBORN CHILD'
#  'AGGRAVATED PO: HANDGUN' 'AGGRAVATED PO: KNIFE/CUT INSTR'
#  'AGGRAVATED PO: OTHER DANG WEAP' 'AGGRAVATED PO: OTHER FIREARM'
#  'AGGRAVATED: HANDGUN' 'AGGRAVATED: OTHER DANG WEAPON'
#  'AGGRAVATED: OTHER FIREARM' 'AGGRAVATED:KNIFE/CUTTING INSTR'
#  'DOMESTIC BATTERY SIMPLE' 'OF UNBORN CHILD' 'PRO EMP HANDS NO/MIN INJURY'
#  'SIMPLE']
# ['AGGRAVATED: HANDGUN' 'AGGRAVATED: KNIFE/CUT INSTR' 'AGGRAVATED: OTHER'
#  'AGGRAVATED: OTHER DANG WEAPON' 'AGGRAVATED: OTHER FIREARM'
#  'ATTEMPT AGG: HANDGUN' 'ATTEMPT AGG: KNIFE/CUT INSTR' 'ATTEMPT AGG: OTHER'
#  'ATTEMPT AGG: OTHER DANG WEAPON' 'ATTEMPT AGG: OTHER FIREARM'
#  'ATTEMPT NON-AGGRAVATED' 'NON-AGGRAVATED' 'PREDATORY']

# %%
print(len(cpd_df[cpd_df['Primary Type'] == 'ROBBERY'][cpd_df['Description'].str.contains("HANDGUN")]))
print(len(cpd_df[cpd_df['Primary Type'] == 'ASSAULT'][cpd_df['Description'].str.contains("HANDGUN")]))
print(len(cpd_df[cpd_df['Primary Type'] == 'WEAPONS VIOLATION'][cpd_df['Description'].str.contains("HANDGUN")]))
print(len(cpd_df[cpd_df['Primary Type'] == 'BATTERY'][cpd_df['Description'].str.contains("HANDGUN")]))
print(len(cpd_df[cpd_df['Primary Type'] == 'CRIM SEXUAL ASSAULT'][cpd_df['Description'].str.contains("HANDGUN")]))
# Out:
# 28957
# 11718
# 13809
# 9069
# 500
# /Applications/anaconda/lib/python3.4/site-packages/pandas/core/frame.py:1825: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
categories = []
categories.append(cpd_df[cpd_df['Primary Type'] == 'HOMICIDE'])
categories.append(cpd_df[cpd_df['Primary Type'] == 'ROBBERY'][cpd_df['Description'].str.contains("HANDGUN")])
categories.append(cpd_df[cpd_df['Primary Type'] == 'ASSAULT'][cpd_df['Description'].str.contains("HANDGUN")])
categories.append(cpd_df[cpd_df['Primary Type'] == 'WEAPONS VIOLATION'][cpd_df['Description'].str.contains("HANDGUN")])
categories.append(cpd_df[cpd_df['Primary Type'] == 'BATTERY'][cpd_df['Description'].str.contains("HANDGUN")])
categories.append(cpd_df[cpd_df['Primary Type'] == 'CRIM SEXUAL ASSAULT'][cpd_df['Description'].str.contains("HANDGUN")])
# Out:
# /Applications/anaconda/lib/python3.4/site-packages/pandas/core/frame.py:1825: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
for i in range(0,len(categories)):
    categories[i] = categories[i][['Primary Type','Date','Latitude','Longitude']].sort('Date').reset_index(drop=True)

# %%
for i in range(0,len(categories)):
    categories[i] = categories[i].as_matrix(columns=categories[i].columns[1:])

# %%
td = categories[0][7][0] - categories[0][0][0]
td
# Out:
# Timedelta('7 days 21:15:00')

# %%
cat = categories[0]
cat[0][1]
# Out:
# 41.766615573

# %%
for cat in categories:
    print(cat)
# Out:
# [[Timestamp('2007-01-01 00:15:00') 41.766615573 -87.674436286]
#  [Timestamp('2007-01-01 02:09:00') 41.891401248 -87.74431476299999]
#  [Timestamp('2007-01-01 03:10:00') 41.838092148 -87.712176626]
#  ...,
#  [Timestamp('2012-12-30 17:10:00') 41.802908524 -87.62104831]
#  [Timestamp('2012-12-31 00:16:00') 41.941077091 -87.732088554]
#  [Timestamp('2012-12-31 16:49:00') 41.85250485 -87.73068709]]
# [[Timestamp('2008-01-01 01:00:00') 41.750549448 -87.62137091299999]
#  [Timestamp('2008-01-01 01:30:00') 41.772084852 -87.67298359899998]
#  [Timestamp('2008-01-01 02:15:00') 41.737413268000005 -87.585217325]
#  ...,
#  [Timestamp('2012-12-31 19:00:00') 41.655796796 -87.596229365]
#  [Timestamp('2012-12-31 19:20:00') 41.744604389 -87.72175209]
#  [Timestamp('2012-12-31 21:00:00') 41.761244993000005 -87.582305221]]
# [[Timestamp('2008-01-01 00:14:00') 41.89106397 -87.768399921]
#  [Timestamp('2008-01-01 00:30:00') 41.779013043 -87.615597022]
#  [Timestamp('2008-01-01 00:49:00') 41.767471672 -87.684541085]
#  ...,
#  [Timestamp('2012-12-31 15:40:00') 41.704106906999996 -87.651146986]
#  [Timestamp('2012-12-31 16:00:00') 41.772035877 -87.67688830700001]
#  [Timestamp('2012-12-31 23:43:00') 41.778656644 -87.66666881299999]]
# [[Timestamp('2008-01-01 00:02:00') 41.891349194 -87.74916693200001]
#  [Timestamp('2008-01-01 00:03:00') 41.87245568 -87.73384827]
#  [Timestamp('2008-01-01 00:03:13') 41.797603035 -87.62092002700001]
#  ...,
#  [Timestamp('2012-12-31 22:18:00') 41.796936816999995 -87.663446505]
#  [Timestamp('2012-12-31 22:18:00') 41.796936816999995 -87.663446505]
#  [Timestamp('2012-12-31 22:25:00') 41.788406688 -87.665651092]]
# [[Timestamp('2008-01-01 00:01:00') 41.808972337 -87.744421231]
#  [Timestamp('2008-01-01 00:45:00') 41.767713198 -87.68454598299999]
#  [Timestamp('2008-01-01 01:20:00') 41.744816062 -87.60378667200001]
#  ...,
#  [Timestamp('2012-12-30 22:05:00') 41.767840782 -87.683327691]
#  [Timestamp('2012-12-31 13:35:00') 41.70240814 -87.63424668799999]
#  [Timestamp('2012-12-31 16:38:00') 41.775346501 -87.666578446]]
# [[Timestamp('2008-01-17 04:30:00') 41.793030995 -87.663325823]
#  [Timestamp('2008-01-22 09:00:00') 41.862379882 -87.716948963]
#  [Timestamp('2008-01-27 18:00:00') 41.729272127 -87.644671198]
#  ...,
#  [Timestamp('2012-12-21 20:00:00') 41.743831177 -87.613409305]
#  [Timestamp('2012-12-28 11:00:00') 41.764206589000004 -87.60324448799999]
#  [Timestamp('2012-12-29 15:15:00') 41.750690464 -87.602741685]]

# %%
num_homicides = len(categories[0])
total_num_crimes = len(categories[0]) + len(categories[1]) + len(categories[2]) + len(categories[3]) + len(categories[4]) + len(categories[5])
print(num_homicides)
print(total_num_crimes)
# Out:
# 2800
# 66853

# %%
#divide categories into sub-time matrices:
homicide_times = [cat[0].timestamp() for cat in categories[0]]
robberies_times = [cat[0].timestamp() for cat in categories[1]]

# %%
'''
Should be arranged in order: Homicides, Robberies, Assaults, Weapons violation, Battery, Crim Sexual Assault
'''
category_times = []
for i in range(0,6):
    category_times.append([cat[0].timestamp() for cat in categories[i]])

# %%
time_matrix = []
for i in range(0,6):
    temp_time_matrix = np.array([category_times[0],]*len(category_times[i])) - np.array([category_times[i],]*len(category_times[0])).transpose()
    temp_time_matrix[temp_time_matrix < 0] = 0
    time_matrix.append(temp_time_matrix)

# %%
time_matrix[5] # time_matrix for sexual assaults
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.56343200e+08,   1.56368760e+08,   1.56428340e+08],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.55895000e+08,   1.55920560e+08,   1.55980140e+08],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.55430600e+08,   1.55456160e+08,   1.55515740e+08],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           7.67400000e+05,   7.92960000e+05,   8.52540000e+05],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.95000000e+05,   2.20560000e+05,   2.80140000e+05],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           9.33000000e+04,   1.18860000e+05,   1.78440000e+05]])

# %%
category_X = []
category_Y = []
for i in range(0,6):
    category_X.append([cat[1] for cat in categories[i]])
    category_Y.append([cat[2] for cat in categories[i]])

# %%
space_matrix = []
for i in range(0,6):
    temp_X_matrix = np.array([category_X[0],]*len(category_X[i])) - np.array([category_X[i],]*len(category_X[0])).transpose()
    temp_Y_matrix = np.array([category_Y[0],]*len(category_Y[i])) - np.array([category_Y[i],]*len(category_Y[0])).transpose()
    temp_time_matrix = temp_X_matrix**2 + temp_Y_matrix**2
    space_matrix.append(temp_time_matrix)
